# %%
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib as mpl
from tensorflow import keras
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

# %% [markdown]
# # basic RNN

# %%
def generate_time_series(batch_size,n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4,batch_size,1)
    time  = np.linspace(0,1,n_steps)
    series = 0.5*np.sin((time-offsets1) * (freq1*10+10))
    series += 0.2*np.sin((time-offsets2) * (freq2*20+20))
    series += 0.1*(np.random.rand(batch_size,n_steps)-0.5)
    return series[..., np.newaxis].astype(np.float32)

# %%
n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None))
save_fig("time_series_plot")
plt.show()
# Out:
# Saving figure time_series_plot

# %%
y_pred = X_valid[:, -1]

plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %% [markdown]
# ### Using a Simple RNN

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

optimizer = keras.optimizers.Adam(lr=0.005)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 5s 731us/sample - loss: 0.0989 - val_loss: 0.0489
# Epoch 2/20
# 7000/7000 [==============================] - 3s 415us/sample - loss: 0.0371 - val_loss: 0.0295
# Epoch 3/20
# 7000/7000 [==============================] - 3s 461us/sample - loss: 0.0249 - val_loss: 0.0218
# Epoch 4/20
# 7000/7000 [==============================] - 4s 517us/sample - loss: 0.0193 - val_loss: 0.0176
# Epoch 5/20
# 7000/7000 [==============================] - 3s 380us/sample - loss: 0.0161 - val_loss: 0.0151
# Epoch 6/20
# 7000/7000 [==============================] - 3s 395us/sample - loss: 0.0141 - val_loss: 0.0135
# Epoch 7/20
# 7000/7000 [==============================] - 4s 502us/sample - loss: 0.0128 - val_loss: 0.0124
# Epoch 8/20
# 7000/7000 [==============================] - 3s 433us/sample - loss: 0.0120 - val_loss: 0.0118
# Epoch 9/20
# 7000/7000 [==============================] - 3s 479us/sample - loss: 0.0114 - val_loss: 0.0114
# Epoch 10/20
# 7000/7000 [==============================] - 3s 401us/sample - loss: 0.0111 - val_loss: 0.0112
# Epoch 11/20
# 7000/7000 [==============================] - 3s 474us/sample - loss: 0.0110 - val_loss: 0.0111
# Epoch 12/20
# 7000/7000 [==============================] - 3s 488us/sample - loss: 0.0110 - val_loss: 0.0111
# Epoch 13/20
# 7000/7000 [==============================] - 3s 405us/sample - loss: 0.0109 - val_loss: 0.0112
# Epoch 14/20
# 7000/7000 [==============================] - 3s 373us/sample - loss: 0.0109 - val_loss: 0.0112
# Epoch 15/20
# 7000/7000 [==============================] - 3s 367us/sample - loss: 0.0109 - val_loss: 0.0111
# Epoch 16/20
# 7000/7000 [==============================] - 3s 359us/sample - loss: 0.0109 - val_loss: 0.0112
# Epoch 17/20
# 7000/7000 [==============================] - 2s 354us/sample - loss: 0.0109 - val_loss: 0.0112
# Epoch 18/20
# 7000/7000 [==============================] - 3s 362us/sample - loss: 0.0109 - val_loss: 0.0111
# Epoch 19/20
# 7000/7000 [==============================] - 3s 366us/sample - loss: 0.0109 - val_loss: 0.0112
# Epoch 20/20
# 7000/7000 [==============================] - 3s 360us/sample - loss: 0.0109 - val_loss: 0.0111

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/2000 [==============================] - 0s 104us/sample - loss: 0.0111
# 0.011145789712667465

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %% [markdown]
# ### Deep RNN

# %%
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0490 - val_loss: 0.0085
# Epoch 2/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0066 - val_loss: 0.0051
# Epoch 3/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0052 - val_loss: 0.0059
# Epoch 4/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0047 - val_loss: 0.0040
# Epoch 5/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0041 - val_loss: 0.0053
# Epoch 6/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0039 - val_loss: 0.0035
# Epoch 7/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0037 - val_loss: 0.0034
# Epoch 8/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0036 - val_loss: 0.0033
# Epoch 9/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0035 - val_loss: 0.0032
# Epoch 10/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0036 - val_loss: 0.0035
# Epoch 11/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0034 - val_loss: 0.0031
# Epoch 12/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0034 - val_loss: 0.0036
# Epoch 13/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0034 - val_loss: 0.0031
# Epoch 14/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0033 - val_loss: 0.0031
# Epoch 15/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0033 - val_loss: 0.0034
# Epoch 16/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0033 - val_loss: 0.0032
# Epoch 17/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0032 - val_loss: 0.0032
# Epoch 18/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0033 - val_loss: 0.0031
# Epoch 19/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0032 - val_loss: 0.0034
# Epoch 20/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0031 - val_loss: 0.0031

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %% [markdown]
# ##### Use a dense layer for tha last layer

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0227 - val_loss: 0.0051
# Epoch 2/20
# 7000/7000 [==============================] - 7s 942us/sample - loss: 0.0041 - val_loss: 0.0036
# Epoch 3/20
# 7000/7000 [==============================] - 6s 887us/sample - loss: 0.0035 - val_loss: 0.0032
# Epoch 4/20
# 7000/7000 [==============================] - 6s 886us/sample - loss: 0.0033 - val_loss: 0.0030
# Epoch 5/20
# 7000/7000 [==============================] - 6s 881us/sample - loss: 0.0032 - val_loss: 0.0031
# Epoch 6/20
# 7000/7000 [==============================] - 6s 875us/sample - loss: 0.0031 - val_loss: 0.0029
# Epoch 7/20
# 7000/7000 [==============================] - 6s 887us/sample - loss: 0.0030 - val_loss: 0.0028
# Epoch 8/20
# 7000/7000 [==============================] - 6s 910us/sample - loss: 0.0030 - val_loss: 0.0029
# Epoch 9/20
# 7000/7000 [==============================] - 6s 886us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 10/20
# 7000/7000 [==============================] - 6s 887us/sample - loss: 0.0030 - val_loss: 0.0028
# Epoch 11/20
# 7000/7000 [==============================] - 6s 888us/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 12/20
# 7000/7000 [==============================] - 6s 878us/sample - loss: 0.0029 - val_loss: 0.0035
# Epoch 13/20
# 7000/7000 [==============================] - 6s 888us/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 14/20
# 7000/7000 [==============================] - 6s 889us/sample - loss: 0.0029 - val_loss: 0.0029
# Epoch 15/20
# 7000/7000 [==============================] - 6s 891us/sample - loss: 0.0029 - val_loss: 0.0030
# Epoch 16/20
# 7000/7000 [==============================] - 6s 886us/sample - loss: 0.0029 - val_loss: 0.0027
# Epoch 17/20
# 7000/7000 [==============================] - 6s 886us/sample - loss: 0.0028 - val_loss: 0.0027
# Epoch 18/20
# 7000/7000 [==============================] - 6s 895us/sample - loss: 0.0028 - val_loss: 0.0029
# Epoch 19/20
# 7000/7000 [==============================] - 6s 887us/sample - loss: 0.0029 - val_loss: 0.0029
# Epoch 20/20
# 7000/7000 [==============================] - 6s 880us/sample - loss: 0.0029 - val_loss: 0.0028

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %% [markdown]
# ### Forecasting Several Steps Ahead

# %%
np.random.seed(43) # not 42, as it would give the first series in the train set

series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]

# %%
Y_pred.shape
# Out:
# (1, 10, 1)

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
save_fig("forecast_ahead_plot")
plt.show()
# Out:
# Saving figure forecast_ahead_plot

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %%
X = X_valid
for step_ahead in range(10):
    y_pred_one = model.predict(X)[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:, 0]

# %%
Y_pred.shape
# Out:
# (2000, 10)

# %% [markdown]
# ### Using the single layer

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 1s 108us/sample - loss: 0.1348 - val_loss: 0.0610
# Epoch 2/20
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.0501 - val_loss: 0.0427
# Epoch 3/20
# 7000/7000 [==============================] - 0s 58us/sample - loss: 0.0388 - val_loss: 0.0356
# Epoch 4/20
# 7000/7000 [==============================] - 0s 57us/sample - loss: 0.0334 - val_loss: 0.0314
# Epoch 5/20
# 7000/7000 [==============================] - 0s 59us/sample - loss: 0.0299 - val_loss: 0.0286
# Epoch 6/20
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.0275 - val_loss: 0.0264
# Epoch 7/20
# 7000/7000 [==============================] - 1s 77us/sample - loss: 0.0258 - val_loss: 0.0251
# Epoch 8/20
# 7000/7000 [==============================] - 0s 67us/sample - loss: 0.0245 - val_loss: 0.0237
# Epoch 9/20
# 7000/7000 [==============================] - 0s 63us/sample - loss: 0.0235 - val_loss: 0.0229
# Epoch 10/20
# 7000/7000 [==============================] - 1s 80us/sample - loss: 0.0227 - val_loss: 0.0222
# Epoch 11/20
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.0221 - val_loss: 0.0220
# Epoch 12/20
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.0216 - val_loss: 0.0212
# Epoch 13/20
# 7000/7000 [==============================] - 0s 65us/sample - loss: 0.0211 - val_loss: 0.0207
# Epoch 14/20
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.0207 - val_loss: 0.0204
# Epoch 15/20
# 7000/7000 [==============================] - 0s 63us/sample - loss: 0.0203 - val_loss: 0.0203
# Epoch 16/20
# 7000/7000 [==============================] - 0s 63us/sample - loss: 0.0200 - val_loss: 0.0198
# Epoch 17/20
# 7000/7000 [==============================] - 0s 60us/sample - loss: 0.0197 - val_loss: 0.0194
# Epoch 18/20
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.0194 - val_loss: 0.0192
# Epoch 19/20
# 7000/7000 [==============================] - 0s 64us/sample - loss: 0.0191 - val_loss: 0.0190
# Epoch 20/20
# 7000/7000 [==============================] - 0s 62us/sample - loss: 0.0189 - val_loss: 0.0188

# %% [markdown]
# ### Using Deep RNN for predictioin

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0665 - val_loss: 0.0317
# Epoch 2/20
# 7000/7000 [==============================] - 7s 968us/sample - loss: 0.0268 - val_loss: 0.0221
# Epoch 3/20
# 7000/7000 [==============================] - 7s 940us/sample - loss: 0.0188 - val_loss: 0.0166
# Epoch 4/20
# 7000/7000 [==============================] - 7s 934us/sample - loss: 0.0159 - val_loss: 0.0137
# Epoch 5/20
# 7000/7000 [==============================] - 6s 923us/sample - loss: 0.0138 - val_loss: 0.0127
# Epoch 6/20
# 7000/7000 [==============================] - 6s 921us/sample - loss: 0.0132 - val_loss: 0.0117
# Epoch 7/20
# 7000/7000 [==============================] - 6s 920us/sample - loss: 0.0119 - val_loss: 0.0117
# Epoch 8/20
# 7000/7000 [==============================] - 7s 944us/sample - loss: 0.0115 - val_loss: 0.0119
# Epoch 9/20
# 7000/7000 [==============================] - 7s 971us/sample - loss: 0.0110 - val_loss: 0.0113
# Epoch 10/20
# 7000/7000 [==============================] - 7s 972us/sample - loss: 0.0111 - val_loss: 0.0097
# Epoch 11/20
# 7000/7000 [==============================] - 6s 918us/sample - loss: 0.0104 - val_loss: 0.0098
# Epoch 12/20
# 7000/7000 [==============================] - 6s 924us/sample - loss: 0.0100 - val_loss: 0.0092
# Epoch 13/20
# 7000/7000 [==============================] - 6s 921us/sample - loss: 0.0101 - val_loss: 0.0101
# Epoch 14/20
# 7000/7000 [==============================] - 6s 916us/sample - loss: 0.0100 - val_loss: 0.0103
# Epoch 15/20
# 7000/7000 [==============================] - 6s 924us/sample - loss: 0.0097 - val_loss: 0.0092
# Epoch 16/20
# 7000/7000 [==============================] - 7s 983us/sample - loss: 0.0094 - val_loss: 0.0088
# Epoch 17/20
# 7000/7000 [==============================] - 7s 937us/sample - loss: 0.0091 - val_loss: 0.0088
# Epoch 18/20
# 7000/7000 [==============================] - 6s 905us/sample - loss: 0.0091 - val_loss: 0.0081
# Epoch 19/20
# 7000/7000 [==============================] - 6s 924us/sample - loss: 0.0089 - val_loss: 0.0079
# Epoch 20/20
# 7000/7000 [==============================] - 6s 900us/sample - loss: 0.0088 - val_loss: 0.0081

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer=keras.optimizers.Adam(lr=0.01), metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 9s 1ms/sample - loss: 0.0498 - last_time_step_mse: 0.0388 - val_loss: 0.0416 - val_last_time_step_mse: 0.0321
# Epoch 2/20
# 7000/7000 [==============================] - 6s 924us/sample - loss: 0.0388 - last_time_step_mse: 0.0281 - val_loss: 0.0332 - val_last_time_step_mse: 0.0223
# Epoch 3/20
# 7000/7000 [==============================] - 7s 933us/sample - loss: 0.0321 - last_time_step_mse: 0.0208 - val_loss: 0.0304 - val_last_time_step_mse: 0.0196
# Epoch 4/20
# 7000/7000 [==============================] - 7s 955us/sample - loss: 0.0294 - last_time_step_mse: 0.0182 - val_loss: 0.0278 - val_last_time_step_mse: 0.0165
# Epoch 5/20
# 7000/7000 [==============================] - 6s 925us/sample - loss: 0.0271 - last_time_step_mse: 0.0153 - val_loss: 0.0262 - val_last_time_step_mse: 0.0141
# Epoch 6/20
# 7000/7000 [==============================] - 7s 939us/sample - loss: 0.0245 - last_time_step_mse: 0.0120 - val_loss: 0.0235 - val_last_time_step_mse: 0.0111
# Epoch 7/20
# 7000/7000 [==============================] - 7s 933us/sample - loss: 0.0227 - last_time_step_mse: 0.0103 - val_loss: 0.0236 - val_last_time_step_mse: 0.0112
# Epoch 8/20
# 7000/7000 [==============================] - 7s 940us/sample - loss: 0.0211 - last_time_step_mse: 0.0085 - val_loss: 0.0197 - val_last_time_step_mse: 0.0071
# Epoch 9/20
# 7000/7000 [==============================] - 7s 940us/sample - loss: 0.0204 - last_time_step_mse: 0.0080 - val_loss: 0.0199 - val_last_time_step_mse: 0.0080
# Epoch 10/20
# 7000/7000 [==============================] - 7s 940us/sample - loss: 0.0198 - last_time_step_mse: 0.0076 - val_loss: 0.0187 - val_last_time_step_mse: 0.0066
# Epoch 11/20
# 7000/7000 [==============================] - 7s 938us/sample - loss: 0.0195 - last_time_step_mse: 0.0074 - val_loss: 0.0189 - val_last_time_step_mse: 0.0069
# Epoch 12/20
# 7000/7000 [==============================] - 7s 935us/sample - loss: 0.0191 - last_time_step_mse: 0.0070 - val_loss: 0.0186 - val_last_time_step_mse: 0.0071
# Epoch 13/20
# 7000/7000 [==============================] - 6s 927us/sample - loss: 0.0187 - last_time_step_mse: 0.0068 - val_loss: 0.0179 - val_last_time_step_mse: 0.0058
# Epoch 14/20
# 7000/7000 [==============================] - 7s 934us/sample - loss: 0.0191 - last_time_step_mse: 0.0073 - val_loss: 0.0184 - val_last_time_step_mse: 0.0068
# Epoch 15/20
# 7000/7000 [==============================] - 7s 941us/sample - loss: 0.0193 - last_time_step_mse: 0.0076 - val_loss: 0.0201 - val_last_time_step_mse: 0.0082
# Epoch 16/20
# 7000/7000 [==============================] - 6s 912us/sample - loss: 0.0186 - last_time_step_mse: 0.0067 - val_loss: 0.0188 - val_last_time_step_mse: 0.0071
# Epoch 17/20
# 7000/7000 [==============================] - 6s 923us/sample - loss: 0.0186 - last_time_step_mse: 0.0069 - val_loss: 0.0174 - val_last_time_step_mse: 0.0059
# Epoch 18/20
# 7000/7000 [==============================] - 7s 1ms/sample - loss: 0.0184 - last_time_step_mse: 0.0067 - val_loss: 0.0172 - val_last_time_step_mse: 0.0058
# Epoch 19/20
# 7000/7000 [==============================] - 7s 948us/sample - loss: 0.0181 - last_time_step_mse: 0.0064 - val_loss: 0.0180 - val_last_time_step_mse: 0.0067
# Epoch 20/20
# 7000/7000 [==============================] - 7s 957us/sample - loss: 0.0180 - last_time_step_mse: 0.0065 - val_loss: 0.0190 - val_last_time_step_mse: 0.0078

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %%
X_train.shape
# Out:
# (7000, 50, 1)

# %% [markdown]
# ### Handling Long Sequences

# %% [markdown]
# ##### Unstable gradients problem

# %% [markdown]
# Using batch Normalization

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.BatchNormalization(),                                          ##After each RNN layer
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.BatchNormalization(),                                          ##After each RNN layer
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))

# %% [markdown]
# Using Layer Normalization

# %%
from tensorflow.keras.layers import LayerNormalization

# %%
class LNSimpleRNNCell(keras.layers.Layer):
    def __init__(self, units, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units,
                                                          activation=None)
        self.layer_norm = LayerNormalization()
        self.activation = keras.activations.get(activation)
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        if inputs is not None:
            batch_size = tf.shape(inputs)[0]
            dtype = inputs.dtype
        return [tf.zeros([batch_size, self.state_size], dtype=dtype)]
    def call(self, inputs, states):
        outputs, new_states = self.simple_rnn_cell(inputs, states)
        norm_outputs = self.activation(self.layer_norm(outputs))
        return norm_outputs, [norm_outputs]

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True,
                     input_shape=[None, 1]),
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 16s 2ms/sample - loss: 0.1539 - last_time_step_mse: 0.1506 - val_loss: 0.0701 - val_last_time_step_mse: 0.0641
# Epoch 2/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0627 - last_time_step_mse: 0.0555 - val_loss: 0.0568 - val_last_time_step_mse: 0.0495
# Epoch 3/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0540 - last_time_step_mse: 0.0463 - val_loss: 0.0502 - val_last_time_step_mse: 0.0423
# Epoch 4/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0472 - last_time_step_mse: 0.0385 - val_loss: 0.0434 - val_last_time_step_mse: 0.0336
# Epoch 5/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0419 - last_time_step_mse: 0.0320 - val_loss: 0.0394 - val_last_time_step_mse: 0.0292
# Epoch 6/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0382 - last_time_step_mse: 0.0272 - val_loss: 0.0363 - val_last_time_step_mse: 0.0246
# Epoch 7/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0362 - last_time_step_mse: 0.0248 - val_loss: 0.0345 - val_last_time_step_mse: 0.0231
# Epoch 8/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0343 - last_time_step_mse: 0.0226 - val_loss: 0.0345 - val_last_time_step_mse: 0.0223
# Epoch 9/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0333 - last_time_step_mse: 0.0216 - val_loss: 0.0338 - val_last_time_step_mse: 0.0219
# Epoch 10/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0326 - last_time_step_mse: 0.0208 - val_loss: 0.0319 - val_last_time_step_mse: 0.0206
# Epoch 11/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0319 - last_time_step_mse: 0.0200 - val_loss: 0.0306 - val_last_time_step_mse: 0.0188
# Epoch 12/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0310 - last_time_step_mse: 0.0190 - val_loss: 0.0303 - val_last_time_step_mse: 0.0185
# Epoch 13/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0306 - last_time_step_mse: 0.0185 - val_loss: 0.0298 - val_last_time_step_mse: 0.0175
# Epoch 14/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0302 - last_time_step_mse: 0.0180 - val_loss: 0.0300 - val_last_time_step_mse: 0.0181
# Epoch 15/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0297 - last_time_step_mse: 0.0174 - val_loss: 0.0290 - val_last_time_step_mse: 0.0164
# Epoch 16/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0294 - last_time_step_mse: 0.0170 - val_loss: 0.0286 - val_last_time_step_mse: 0.0166
# Epoch 17/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0286 - last_time_step_mse: 0.0160 - val_loss: 0.0286 - val_last_time_step_mse: 0.0158
# Epoch 18/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0284 - last_time_step_mse: 0.0158 - val_loss: 0.0277 - val_last_time_step_mse: 0.0144
# Epoch 19/20
# 7000/7000 [==============================] - 12s 2ms/sample - loss: 0.0277 - last_time_step_mse: 0.0149 - val_loss: 0.0274 - val_last_time_step_mse: 0.0141
# Epoch 20/20
# 7000/7000 [==============================] - 13s 2ms/sample - loss: 0.0273 - last_time_step_mse: 0.0144 - val_loss: 0.0267 - val_last_time_step_mse: 0.0132

# %% [markdown]
# ### Creating a Custom RNN Class

# %%
class MyRNN(keras.layers.Layer):
    def __init__(self, cell, return_sequences=False, **kwargs):
        super().__init__(**kwargs)
        self.cell = cell
        self.return_sequences = return_sequences
        self.get_initial_state = getattr(
            self.cell, "get_initial_state", self.fallback_initial_state)
    def fallback_initial_state(self, inputs):
        return [tf.zeros([self.cell.state_size], dtype=inputs.dtype)]
    @tf.function
    def call(self, inputs):
        states = self.get_initial_state(inputs)
        n_steps = tf.shape(inputs)[1]
        if self.return_sequences:
            sequences = tf.TensorArray(inputs.dtype, size=n_steps)
        outputs = tf.zeros(shape=[n_steps, self.cell.output_size], dtype=inputs.dtype)
        for step in tf.range(n_steps):
            outputs, states = self.cell(inputs[:, step], states)
            if self.return_sequences:
                sequences = sequences.write(step, outputs)
        if self.return_sequences:
            return sequences.stack()
        else:
            return outputs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    MyRNN(LNSimpleRNNCell(20), return_sequences=True,
          input_shape=[None, 1]),
    MyRNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))

# %% [markdown]
# # LSTM

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 14s 2ms/sample - loss: 0.0760 - last_time_step_mse: 0.0615 - val_loss: 0.0554 - val_last_time_step_mse: 0.0372
# Epoch 2/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0480 - last_time_step_mse: 0.0281 - val_loss: 0.0423 - val_last_time_step_mse: 0.0211
# Epoch 3/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0390 - last_time_step_mse: 0.0182 - val_loss: 0.0371 - val_last_time_step_mse: 0.0164
# Epoch 4/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0350 - last_time_step_mse: 0.0151 - val_loss: 0.0335 - val_last_time_step_mse: 0.0143
# Epoch 5/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0325 - last_time_step_mse: 0.0136 - val_loss: 0.0314 - val_last_time_step_mse: 0.0124
# Epoch 6/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0308 - last_time_step_mse: 0.0123 - val_loss: 0.0297 - val_last_time_step_mse: 0.0108
# Epoch 7/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0297 - last_time_step_mse: 0.0117 - val_loss: 0.0289 - val_last_time_step_mse: 0.0106
# Epoch 8/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0286 - last_time_step_mse: 0.0108 - val_loss: 0.0279 - val_last_time_step_mse: 0.0103
# Epoch 9/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0280 - last_time_step_mse: 0.0106 - val_loss: 0.0279 - val_last_time_step_mse: 0.0111
# Epoch 10/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0274 - last_time_step_mse: 0.0105 - val_loss: 0.0270 - val_last_time_step_mse: 0.0103
# Epoch 11/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0268 - last_time_step_mse: 0.0100 - val_loss: 0.0264 - val_last_time_step_mse: 0.0097
# Epoch 12/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0264 - last_time_step_mse: 0.0099 - val_loss: 0.0263 - val_last_time_step_mse: 0.0108
# Epoch 13/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0259 - last_time_step_mse: 0.0096 - val_loss: 0.0257 - val_last_time_step_mse: 0.0094
# Epoch 14/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0257 - last_time_step_mse: 0.0096 - val_loss: 0.0264 - val_last_time_step_mse: 0.0110
# Epoch 15/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0253 - last_time_step_mse: 0.0095 - val_loss: 0.0253 - val_last_time_step_mse: 0.0096
# Epoch 16/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0250 - last_time_step_mse: 0.0092 - val_loss: 0.0248 - val_last_time_step_mse: 0.0091
# Epoch 17/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0247 - last_time_step_mse: 0.0092 - val_loss: 0.0245 - val_last_time_step_mse: 0.0087
# Epoch 18/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0245 - last_time_step_mse: 0.0092 - val_loss: 0.0242 - val_last_time_step_mse: 0.0092
# Epoch 19/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0242 - last_time_step_mse: 0.0089 - val_loss: 0.0237 - val_last_time_step_mse: 0.0084
# Epoch 20/20
# 7000/7000 [==============================] - 11s 2ms/sample - loss: 0.0239 - last_time_step_mse: 0.0089 - val_loss: 0.0240 - val_last_time_step_mse: 0.0086

# %% [markdown]
# # GRU

# %%
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])my

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid",
                        input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train[:, 3::2], epochs=20,
                    validation_data=(X_valid, Y_valid[:, 3::2]))

# %% [markdown]
# # WaveNet

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
